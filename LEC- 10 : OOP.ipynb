# %%
print("Hello World")
# Out:
# Hello World

# %%
class car:
    a = 10
    b = 100
bmw = car.a
bmw
# Out:
# 10

# %%
# Define a Class : Car
class car:
    # Define Feactures of Class "Car" : Features / Variable
    no_of_wheel = 4
    no_of_door = 4
    color ="Red"
    # define a  SoundFunction of class "Car"  : Function / Method
    def sound():
        print("Honk")
# Create a object bmw, audi and Maruti of class "Car"
bwm = car.no_of_door  # feature no_of_wheel been accesss with . operator
print(bwm)
audi = car.sound()  # define  sound () benn access with . operator
print(audi)
maruti = car.color  # feature color been access with  operator
print(maruti)
# Out:
# 4
# Honk
# Red
